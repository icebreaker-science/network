# %% [markdown]
# # Reduce number of wikidata keywords
# Reduce the number of entries from wikidata by searching wikidata for the top N hits.
# Should remove unnecessary entries like ships or horses that have the name of a keyword.
#
# Expect csv `keyword_wikidata.csv` with columns keyword, wikidata and parent0.

# %%
#config

#path where csv files are stored
data_path = '../../../../data'

# use top n hits
top_n = 5

# load search result from file search_result.csv
load_search = True

# %%
import os
import pandas as pd
import copy
import sys
import requests
from tqdm import tqdm

# %%
# load csv
keyword_wiki_path = os.path.join(data_path, 'keyword_wikidata.csv')
df_keywords_wiki = pd.read_csv(keyword_wiki_path, index_col='wikidata')

# %%
# group keywords by there number of entries
most_multiples =  df_keywords_wiki.groupby('keyword').agg(['count'])
most_multiples = most_multiples.droplevel(0, axis=1).sort_values('count', ascending=False)
most_multiples[:5]
# Out:
#               count
# keyword
# erratum        9807
# editorial      7647
# correction     6857
# book reviews   5925
# reviews        5423

# %%
# select the keywords that have more than top_n entries

multiples = most_multiples[most_multiples['count'] > top_n]
keyword_list = multiples.index.tolist()

# %%
api = "https://www.wikidata.org/w/api.php"

params = {
    'action':'wbsearchentities',
    'format':'json',
    'language':'en',
    'type':'item',
    'continue': 0,
    'limit': top_n,
    'search': 'erratum',
}


def search_wikidata(keyword):
    params['search'] = keyword
    r = requests.get(url = api, params = params)
    data = r.json()
    ds = []
    for d in data['search']:
        label = d['label'].lower()
        id = d['id']
        if 'description' in d:
            description = d['description']
        else:
            description = ''
        ds.append((id, label, description))
    return ds

# %%
# example search

search_wikidata('erratum')
# Out:
# [('Q1348305', 'erratum', 'published correction to a previous publication'),
#  ('Q28948209',
#   'erratum',
#   'scientific article (publication date: 30 August 2016)'),
#  ('Q58375287', 'erratum', 'scientific article published on 01 July 1992'),
#  ('Q56084196', 'erratum', ''),
#  ('Q58937358', 'erratum', '')]

# %%
# search wikidata for all keywords

def get_keywords_from_wikidata():
    searchedIds = pd.DataFrame(columns=['keyword', 'id', 'label', 'description', 'hit'])

    count = 0
    try:
        for k in tqdm(keyword_list):
            data = search_wikidata(k)
            for i, d in enumerate(data):
                searchedIds = searchedIds.append({'keyword': k, 'id': d[0], 'label': d[1], 'description': d[2], 'hit': i}, ignore_index=True)
            count += 1
    except:
        print(count)

    print(count)
    return searchedIds

# %%
# load search results

search_result_path = os.path.join(data_path, 'search_result.csv')

if load_search:
    searchedIds = pd.read_csv(search_result_path, index_col=0)
else:
    searchedIds = get_keywords_from_wikidata()
    searchedIds.to_csv(search_result_path)

# %%
# check results
searchedIds
# Out:
#         keyword         id             label  \
# 0       erratum   Q1348305           erratum
# 1       erratum  Q28948209           erratum
# 2       erratum  Q58375287           erratum
# 3       erratum  Q56084196           erratum
# 4       erratum  Q58937358           erratum
# ...         ...        ...               ...
# 31275  mediator  Q14886885  mediator complex
# 31276  mediator   Q1666223      intermediary
# 31277  mediator   Q4859473          mediator
# 31278  mediator    Q421695        benfluorex
# 31279  mediator  Q29678902            mdt-31
#
#                                              description  hit
# 0         published correction to a previous publication    0
# 1      scientific article (publication date: 30 Augus...    1
# 2           scientific article published on 01 July 1992    2
# 3                                                    NaN    3
# 4                                                    NaN    4
# ...                                                  ...  ...
# 31275  A protein complex that interacts with the carb...    0
# 31276  third party that offers intermediation service...    1
# 31277                                         profession    2
# 31278            chemical compound used as diabetes drug    3
# 31279  protein-coding gene in the species Caenorhabdi...    4
#
# [31280 rows x 5 columns]

# %%
# keyword and label of the result does not always match
searchedIds[searchedIds.keyword != searchedIds.label]
# Out:
#                 keyword         id  \
# 10           correction   Q1348305
# 11           correction  Q45203135
# 12           correction   Q3633148
# 14           correction     Q40357
# 32         introduction  Q28764881
# ...                 ...        ...
# 31257  medical sciences  Q26332849
# 31275          mediator  Q14886885
# 31276          mediator   Q1666223
# 31278          mediator    Q421695
# 31279          mediator  Q29678902
#
#                                                    label  \
# 10                                               erratum
# 11                                            retraction
# 12                        hajipur lok sabha constituency
# 14                                                prison
# 32     introduction. taxonomy for the twenty-first ce...
# ...                                                  ...
# 31257  danish council for independent research | medi...
# 31275                                   mediator complex
# 31276                                       intermediary
# 31278                                         benfluorex
# 31279                                             mdt-31
#
#                                              description  hit
# 10        published correction to a previous publication    0
# 11     act of withdrawing, refuting, or reversing an ...    1
# 12                       Lok Sabha Constituency in Bihar    2
# 14     place in which people legally are physically c...    4
# 32                                    scientific article    2
# ...                                                  ...  ...
# 31257                                                NaN    2
# 31275  A protein complex that interacts with the carb...    0
# 31276  third party that offers intermediation service...    1
# 31278            chemical compound used as diabetes drug    3
# 31279  protein-coding gene in the species Caenorhabdi...    4
#
# [7405 rows x 5 columns]

# %%
# filter entries
keywords_wiki_small = df_keywords_wiki[~df_keywords_wiki.keyword.isin(multiples.index) | df_keywords_wiki.index.isin(searchedIds.id)]
keywords_wiki_small
# Out:
#                            keyword                     parent0
# wikidata
# P5483                     hardness  ["Q22963600", "Q22981316"]
# Q28578                    appetite                         NaN
# P5520                    toughness  ["Q22963600", "Q22981316"]
# Q2878286   squamous cell carcinoma                         NaN
# Q2880099                     femur                         NaN
# ...                            ...                         ...
# Q9195957          network dynamics                         NaN
# Q9251921        magnetic shielding                         NaN
# Q9282312              marine fungi                         NaN
# Q28469711                    first                         NaN
# P5460                       grants  ["Q22984450", "Q56150830"]
#
# [61221 rows x 2 columns]

# %%
# save filtered entries to file
keyword_wiki_small_path = os.path.join(data_path, 'keyword_wikidata_small.csv')
keywords_wiki_small.to_csv(keyword_wiki_small_path)

# %%
# original number of entries
df_keywords_wiki.count()
# Out:
# keyword    231885
# parent0    223991
# dtype: int64

# %%
# filterd number of entries
keywords_wiki_small.count()
# Out:
# keyword    61221
# parent0    56360
# dtype: int64
